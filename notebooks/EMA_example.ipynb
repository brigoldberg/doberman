# %%
import sys
import os
app_path = os.path.join(os.path.expanduser('~/sandbox/doberman/'))
sys.path.append(app_path)

import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator
from doberman import Universe
from doberman import EMA

stock_list = ['aapl', 'xom']
universe = Universe(stock_list)

# %%
universe.load_data()
universe.align_dates('2020-01-01', '2020-12-31')

# %%
ema = EMA(universe)

# %%
ticker_name = 'xom'
fig, (ax1, ax2) = plt.subplots(2, figsize=(24, 20), sharex=True)
ax1.universe.stocks[ticker_name].tsdb['adj_close'].plot()
ax1.universe.stocks[ticker_name].tsdb['ema'].plot()
ax1.legend()
ax1.xaxis.set_major_locator(MonthLocator())
ax2.universe.stocks[ticker_name].tsdb['histogram'].plot(ax=ax2, kind='bar', color='b')
ax2.legend()
ax2.xaxis.set_major_locator(MonthLocator())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hh/8303q_2j7774d8mgs2jlxg5r0000gn/T/ipykernel_5455/2869319382.py in <module>
#       1 ticker_name = 'xom'
#       2 fig, (ax1, ax2) = plt.subplots(2, figsize=(24, 20), sharex=True)
# ----> 3 ax1.universe.stocks[ticker_name].tsdb['adj_close'].plot()
#       4 ax1.universe.stocks[ticker_name].tsdb['ema'].plot()
#       5 ax1.legend()
#
# AttributeError: 'AxesSubplot' object has no attribute 'universe'
