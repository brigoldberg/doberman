# %%
import sys
import os
import pprint
app_path = os.path.join(os.path.expanduser('~/sandbox/doberman/'))
sys.path.append(app_path)
from doberman import Stock
from doberman import MACD
from doberman import Simulation
from doberman import DoberPlot

# %%
# Create 'stock_obj'
ticker = 'nvda'
stock = Stock(ticker)
stock.load_data()
stock.snip_dates('2019-01-01', '2020-12-31')

# %%
# Calculate MACD signals
macd_signal = MACD(stock)

# %%
# %%time
# Run simulation
sim = Simulation(macd_signal.stock_obj)
sim.paper_trade()
# Out:
# CPU times: user 4.9 s, sys: 110 ms, total: 5.01 s
# Wall time: 5.03 s

# %%
sim.calc_pnl()
# Out:
# nvda simulation PnL: $112,711

# %%
doberplot = DoberPlot(stock)

# %%
doberplot.order_signal(strategy_name='macd')

# %%
doberplot.macd_histogram()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hh/8303q_2j7774d8mgs2jlxg5r0000gn/T/ipykernel_8249/3391280743.py in <module>
# ----> 1 doberplot.macd_histogram()
#
# AttributeError: 'DoberPlot' object has no attribute 'macd_histogram'
